# %%
import os
data_set_dir = 'C:/Users/USER/Desktop/Assignment 2 file/Data set/facemask dataset/'
train_data_dir = os.path.join(data_set_dir, 'Train' )
test_data_dir = os.path.join(data_set_dir, "Test")
validation_data_dir = os.path.join(data_set_dir, "Validation")

# %%
CATEGORIES = []
for i in os.listdir(train_data_dir):
  CATEGORIES.append(i)
print(CATEGORIES)
# Out:
# ['WithMask', 'WithoutMask']

# %%
import matplotlib.pyplot as plt
import cv2
i = 0
plt.figure(figsize=(20,5))
for c in CATEGORIES:
  path = os.path.join(train_data_dir,c)
  for img in os.listdir(path):
    plt.subplot(2,10,i+1)
    img_arr = plt.imread(os.path.join(path,img))
    img_arr = cv2.resize(img_arr, (227,227))
    # img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BRG2RGB)
    plt.imshow(img_arr)
    if i%10 ==0:
      plt.ylabel(c, size=20)
    plt.xticks([])
    plt.yticks([])
    i += 1
    if i%10 == 0:
      break

plt.show()

# %%
train_data = []
i = 0;
for c in CATEGORIES:
  path = os.path.join(train_data_dir,c)
  for img in os.listdir(path):
    img_arr = plt.imread(os.path.join(path,img))
    img_arr = cv2.resize(img_arr, (227,227))
    train_data.append([img_arr, CATEGORIES.index(c)])
    i = i +1
    if i % 1000 == 0:
      break
print(len(train_data))
# Out:
# 2000

# %%
valid_data = []
i = 0;
for c in CATEGORIES:
  path = os.path.join(validation_data_dir,c)
  for img in os.listdir(path):
    img_arr = plt.imread(os.path.join(path,img))
    img_arr = cv2.resize(img_arr, (227,227))
    valid_data.append([img_arr, CATEGORIES.index(c)])
    i = i +1
    if i % 200 == 0:
      break
print(len(valid_data))
# Out:
# 400

# %%
test_data = []
i = 0;
for c in CATEGORIES:
  path = os.path.join(test_data_dir,c)
  for img in os.listdir(path):
    img_arr = plt.imread(os.path.join(path,img))
    img_arr = cv2.resize(img_arr, (227,227))
    test_data.append([img_arr, CATEGORIES.index(c)])
    i = i +1
    if i % 200 == 0:
      break
print(len(test_data))
# Out:
# 400

# %%
import random
random.shuffle(train_data)
random.shuffle(test_data)
random.shuffle(valid_data)

# %%
import numpy as np

# %%
X_train = []
Y_train = []
i = 0
for img, label in train_data:
  X_train.append(img)
  Y_train.append(label)
X_train = (np.array(X_train)*255).astype('float32').reshape(-1,227,227,3)
Y_train = np.array(Y_train)
print(X_train.shape, Y_train.shape)
# Out:
# (2000, 227, 227, 3) (2000,)

# %%
X_valid = []
Y_valid = []
for img, label in valid_data:
  X_valid.append(img)
  Y_valid.append(label)
X_valid = (np.array(X_valid)*255).astype('float32').reshape(-1,227,227,3)
Y_valid = np.array(Y_valid)

print(X_valid.shape, Y_valid.shape)
# Out:
# (400, 227, 227, 3) (400,)

# %%
X_test = []
Y_test = []
for img, label in test_data:
  X_test.append(img)
  Y_test.append(label)
X_test = (np.array(X_test)*255).astype('float32').reshape(-1,227,227,3)
Y_test = np.array(Y_test)

print(X_test.shape, Y_test.shape)
# Out:
# (400, 227, 227, 3) (400,)

# %%
mean_img = np.mean(X_train, axis=0)
plt.imshow(mean_img.astype('uint8'))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential([
    keras.Input(shape=X_train.shape[1:]),
    layers.Conv2D(filters=96, kernel_size=(11,11),strides=(4,4), padding='valid', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.BatchNormalization(),

    layers.Conv2D(filters=256, kernel_size=(5,5),strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.BatchNormalization(),

    layers.Conv2D(filters=384, kernel_size=(3,3),strides=(1,1), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.Conv2D(filters=384, kernel_size=(3,3),strides=(1,1), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=256, kernel_size=(3,3),strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(units=4096, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(units=4096, activation='relu'),
    layers.Dropout(0.4),
    layers.BatchNormalization(),
    layers.Dense(units=1, activation='sigmoid')

])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 55, 55, 96)        34944
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 13, 13, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 13, 13, 384)       885120
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 13, 13, 384)       1536
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 384)       1327488
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 13, 13, 384)       1536
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 13, 13, 256)       884992
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              37752832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 4097
# =================================================================
# Total params: 58,323,713
# Trainable params: 58,304,577
# Non-trainable params: 19,136
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    loss=tf.keras.losses.binary_crossentropy,
    metrics=['accuracy']
)

# %%
h = model.fit(x=X_train, y=Y_train, epochs=50, batch_size=64, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 168s 5s/step - loss: 0.3519 - accuracy: 0.8445 - val_loss: 0.7004 - val_accuracy: 0.5850
# Epoch 2/50
# 32/32 [==============================] - 192s 6s/step - loss: 0.1166 - accuracy: 0.9565 - val_loss: 0.4466 - val_accuracy: 0.9250
# Epoch 3/50
# 32/32 [==============================] - 188s 6s/step - loss: 0.0671 - accuracy: 0.9770 - val_loss: 0.3280 - val_accuracy: 0.9600
# Epoch 4/50
# 32/32 [==============================] - 186s 6s/step - loss: 0.0510 - accuracy: 0.9860 - val_loss: 0.1886 - val_accuracy: 0.9825
# Epoch 5/50
# 32/32 [==============================] - 196s 6s/step - loss: 0.0376 - accuracy: 0.9895 - val_loss: 0.1181 - val_accuracy: 0.9800
# Epoch 6/50
# 32/32 [==============================] - 193s 6s/step - loss: 0.0287 - accuracy: 0.9925 - val_loss: 0.0536 - val_accuracy: 1.0000
# Epoch 7/50
# 32/32 [==============================] - 189s 6s/step - loss: 0.0227 - accuracy: 0.9955 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 8/50
# 32/32 [==============================] - 188s 6s/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 9/50
# 32/32 [==============================] - 185s 6s/step - loss: 0.0140 - accuracy: 0.9975 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 10/50
# 32/32 [==============================] - 186s 6s/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 11/50
# 32/32 [==============================] - 187s 6s/step - loss: 0.0115 - accuracy: 0.9985 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 12/50
# 32/32 [==============================] - 186s 6s/step - loss: 0.0085 - accuracy: 0.9985 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 13/50
# 32/32 [==============================] - 189s 6s/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 14/50
# 32/32 [==============================] - 190s 6s/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 15/50
# 32/32 [==============================] - 198s 6s/step - loss: 0.0109 - accuracy: 0.9950 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 16/50
# 32/32 [==============================] - 172s 5s/step - loss: 0.0089 - accuracy: 0.9985 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 17/50
# 32/32 [==============================] - 172s 5s/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 18/50
# 32/32 [==============================] - 170s 5s/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 19/50
# 32/32 [==============================] - 170s 5s/step - loss: 0.0065 - accuracy: 0.9990 - val_loss: 8.9782e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 32/32 [==============================] - 173s 5s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 4.9263e-04 - val_accuracy: 1.0000
# Epoch 21/50
# 32/32 [==============================] - 180s 6s/step - loss: 0.0069 - accuracy: 0.9990 - val_loss: 4.9538e-04 - val_accuracy: 1.0000
# Epoch 22/50
# 32/32 [==============================] - 160s 5s/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 23/50
# 32/32 [==============================] - 161s 5s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.2091e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 32/32 [==============================] - 161s 5s/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 6.8542e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 32/32 [==============================] - 161s 5s/step - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 26/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 5.2894e-04 - val_accuracy: 1.0000
# Epoch 27/50
# 32/32 [==============================] - 161s 5s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.7710e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.1194e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 32/32 [==============================] - 161s 5s/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 2.8055e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 32/32 [==============================] - 169s 5s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.8772e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 32/32 [==============================] - 166s 5s/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 1.6671e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 32/32 [==============================] - 164s 5s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.7691e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.7017e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 3.8632e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 32/32 [==============================] - 161s 5s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.4091e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 32/32 [==============================] - 165s 5s/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 3.1574e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 32/32 [==============================] - 165s 5s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1983e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 32/32 [==============================] - 163s 5s/step - loss: 7.7101e-04 - accuracy: 1.0000 - val_loss: 8.3740e-05 - val_accuracy: 1.0000
# Epoch 39/50
# 32/32 [==============================] - 163s 5s/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 8.7267e-05 - val_accuracy: 1.0000
# Epoch 40/50
# 32/32 [==============================] - 166s 5s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3690e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 32/32 [==============================] - 163s 5s/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 1.7309e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 32/32 [==============================] - 163s 5s/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 1.5863e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.0214 - val_accuracy: 0.9950
# Epoch 44/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0152 - val_accuracy: 0.9950
# Epoch 45/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 7.4475e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 32/32 [==============================] - 161s 5s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.0049e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.5902e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 32/32 [==============================] - 162s 5s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0222e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 32/32 [==============================] - 164s 5s/step - loss: 7.6126e-04 - accuracy: 1.0000 - val_loss: 6.0752e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 32/32 [==============================] - 162s 5s/step - loss: 4.3585e-04 - accuracy: 1.0000 - val_loss: 6.1119e-05 - val_accuracy: 1.0000

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 [==============================] - 6s 454ms/step - loss: 6.1119e-05 - accuracy: 1.0000
# [6.111919356044382e-05, 1.0]

# %%
model.save('C:/Users/USER/Desktop/Assignment 2 file/Code/run/Model 1')
# Out:
# WARNING:tensorflow:From C:\Users\USER\anaconda3\envs\cvpr\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\USER\anaconda3\envs\cvpr\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:/Users/USER/Desktop/Assignment 2 file/Code/run/Model 1\assets
